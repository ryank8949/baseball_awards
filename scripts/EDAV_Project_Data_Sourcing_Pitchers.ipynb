# %%
# pip install pybaseball

# %%
from pybaseball import pitching_stats
from pybaseball import batting_stats
import pandas as pd

# %% [markdown]
# ### Importing pitching statistics via pybaseball library

# %%
data_1 = pitching_stats(1911,1917, qual=40)
data_2 = pitching_stats(1918,1919, qual=30)
data_3 = pitching_stats(1920, qual=40)
data_4 = pitching_stats(1921,1930, qual=40)
data_5 = pitching_stats(1931,1940, qual=40)
data_6 = pitching_stats(1941,1950, qual=40)
data_7 = pitching_stats(1951,1960, qual=40)
data_8 = pitching_stats(1961,1970, qual=40)
data_9 = pitching_stats(1971, qual=40)
data_10 = pitching_stats(1972, qual=35)
data_11 = pitching_stats(1973,1980, qual=40)
data_12 = pitching_stats(1981, qual=20)
data_13 = pitching_stats(1982,1990, qual=40)
data_14 = pitching_stats(1991,1993, qual=40)
data_15 = pitching_stats(1994,1995, qual=30)
data_16 = pitching_stats(1996,2000, qual=40)
data_17 = pitching_stats(2001,2010, qual=40)
data_18 = pitching_stats(2011,2019, qual=40)
data_19 = pitching_stats(2020, qual=5)
data_20 = pitching_stats(2021,2025, qual=40)

# %%
import pandas as pd
df = pd.concat([data_1, data_2, data_3, data_4, data_5, data_6, data_7, data_8, data_9, data_10, data_11, data_12,
               data_13, data_14, data_15, data_16, data_17, data_18, data_19, data_20], ignore_index=True)

# %%
df.shape
# Out:
# (28649, 393)

# %%
df.head()
# Out:
#       IDfg  Season            Name Team  Age   W   L  WAR   ERA   G  ...  \
# 0  1000128    1915  Pete Alexander  PHI   28  31  10  9.6  1.22  49  ...
# 1  1006511    1912  Walter Johnson  WAS   24  33  12  9.3  1.39  50  ...
# 2  1000128    1917  Pete Alexander  PHI   30  30  13  9.0  1.83  45  ...
# 3  1003913    1914   Cy Falkenberg  IND   33  25  16  9.0  2.22  49  ...
# 4  1006511    1916  Walter Johnson  WAS   28  25  20  8.8  1.90  48  ...
#
#    Pit+ FC  Stf+ FS  Loc+ FS  Pit+ FS  Stuff+  Location+  Pitching+  Stf+ FO  \
# 0      NaN      NaN      NaN      NaN     NaN        NaN        NaN      NaN
# 1      NaN      NaN      NaN      NaN     NaN        NaN        NaN      NaN
# 2      NaN      NaN      NaN      NaN     NaN        NaN        NaN      NaN
# 3      NaN      NaN      NaN      NaN     NaN        NaN        NaN      NaN
# 4      NaN      NaN      NaN      NaN     NaN        NaN        NaN      NaN
#
#    Loc+ FO  Pit+ FO
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
# [5 rows x 393 columns]

# %%
df.to_csv('/Users/ryan/Desktop/STAT5702GR/final_project/pitching_stats.csv')

# %%
dfp = pd.read_csv('/Users/ryan/Desktop/STAT5702GR/final_project/pitching_stats.csv')
# Out:
# /var/folders/zl/m7fg_jqs4hgg12s5y0wr8yyc0000gn/T/ipykernel_46242/1440289580.py:1: DtypeWarning: Columns (62) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfp = pd.read_csv('/Users/ryan/Desktop/STAT5702GR/final_project/pitching_stats.csv')

# %%
dfp.head()
# Out:
#    Unnamed: 0     IDfg  Season            Name Team  Age   W   L  WAR   ERA  \
# 0           0  1000128    1915  Pete Alexander  PHI   28  31  10  9.6  1.22
# 1           1  1006511    1912  Walter Johnson  WAS   24  33  12  9.3  1.39
# 2           2  1000128    1917  Pete Alexander  PHI   30  30  13  9.0  1.83
# 3           3  1003913    1914   Cy Falkenberg  IND   33  25  16  9.0  2.22
# 4           4  1006511    1916  Walter Johnson  WAS   28  25  20  8.8  1.90
#
#    ...  Pit+ FC  Stf+ FS  Loc+ FS  Pit+ FS  Stuff+  Location+  Pitching+  \
# 0  ...      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 1  ...      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 2  ...      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 3  ...      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 4  ...      NaN      NaN      NaN      NaN     NaN        NaN        NaN
#
#    Stf+ FO  Loc+ FO  Pit+ FO
# 0      NaN      NaN      NaN
# 1      NaN      NaN      NaN
# 2      NaN      NaN      NaN
# 3      NaN      NaN      NaN
# 4      NaN      NaN      NaN
#
# [5 rows x 394 columns]

# %% [markdown]
# ### Lahman Data

# %%
df_awards = pd.read_csv('/Users/ryan/Desktop/STAT5702GR/final_project/AwardsPlayers.csv')
df_people = pd.read_csv('/Users/ryan/Desktop/STAT5702GR/final_project/People.csv')
df_teams = pd.read_csv('/Users/ryan/Desktop/STAT5702GR/final_project/Teams.csv')

# %% [markdown]
# ### Translation_Table

# %%
import warnings
warnings.filterwarnings("ignore", category=pd.errors.DtypeWarning)

# %%
from pathlib import Path

folder = Path("/Users/ryan/Desktop/STAT5702GR/final_project/ids")

# Get all CSV files
files = list(folder.glob("*.csv"))

# Read and concatenate
tr_table = pd.concat((pd.read_csv(f) for f in files), ignore_index=True)

print("Combined shape:", tr_table.shape)
tr_table.head()
# Out:
# Combined shape: (510391, 40)
#   key_person                              key_uuid  key_mlbam key_retro  \
# 0   80003c98  80003c98-3fe9-472c-8d38-4d63103b9ec6        NaN       NaN
# 1   800042d1  800042d1-8bf8-4309-abd7-b2e87231ec3d        NaN       NaN
# 2   8000b024  8000b024-c085-4d27-8da1-8febbc6210bf        NaN       NaN
# 3   8000b814  8000b814-5d4c-4e6d-a9f3-02a0fefeb99b        NaN       NaN
# 4   8001148e  8001148e-185f-4647-a13b-1e7cca877432        NaN       NaN
#
#   key_bbref key_bbref_minors  key_fangraphs  key_npb key_sr_nfl key_sr_nba  \
# 0       NaN     shelto009---            NaN      NaN        NaN        NaN
# 1       NaN     pavlis000jac            NaN      NaN        NaN        NaN
# 2       NaN     padill005jos            NaN      NaN        NaN        NaN
# 3       NaN     kim---000han            NaN      NaN        NaN        NaN
# 4       NaN     crogha000eri            NaN      NaN        NaN        NaN
#
#    ... pro_managed_first pro_managed_last mlb_managed_first mlb_managed_last  \
# 0  ...               NaN              NaN               NaN              NaN
# 1  ...               NaN              NaN               NaN              NaN
# 2  ...               NaN              NaN               NaN              NaN
# 3  ...               NaN              NaN               NaN              NaN
# 4  ...               NaN              NaN               NaN              NaN
#
#   col_managed_first col_managed_last pro_umpired_first pro_umpired_last  \
# 0               NaN              NaN               NaN              NaN
# 1               NaN              NaN               NaN              NaN
# 2               NaN              NaN               NaN              NaN
# 3               NaN              NaN               NaN              NaN
# 4               NaN              NaN               NaN              NaN
#
#    mlb_umpired_first  mlb_umpired_last
# 0                NaN               NaN
# 1                NaN               NaN
# 2                NaN               NaN
# 3                NaN               NaN
# 4                NaN               NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Merging Data

# %% [markdown]
# Player ID translation file to merge the Lahman dataframes to the pybaseball dataframes

# %%
import pandas as pd

# -------------------------------------------------------------------
# 1. Join Lahman awards (df_awards) to Lahman people (df_people)
# -------------------------------------------------------------------

# Keep only needed columns from Lahman People
people_cols = ["playerID", "bbrefID", "nameFirst", "nameLast"]
people_subset = df_people[people_cols].copy()

# Merge awards with people on playerID
lahman_awards = df_awards.merge(
    people_subset,
    on="playerID",
    how="left",
    validate="m:1"   # many awards → one people record
)

# Optional: create full name (purely cosmetic)
lahman_awards["full_name"] = (
    lahman_awards["nameFirst"].fillna("") + " " +
    lahman_awards["nameLast"].fillna("")
).str.strip()


# -------------------------------------------------------------------
# 2. Use translation table (tr_table) to attach FanGraphs ID to Lahman
# -------------------------------------------------------------------

# Ensure IDs are strings
lahman_awards["bbrefID"]      = lahman_awards["bbrefID"].astype(str)
tr_table["key_bbref"]         = tr_table["key_bbref"].astype(str)
# tr_table["key_fangraphs"]     = tr_table["key_fangraphs"].astype(str)
# dfp["IDfg"]                   = dfp["IDfg"].astype(str)

# Deduplicate translation table on bbref key (safety measure)
tr_table_dedup = tr_table.drop_duplicates(subset=["key_bbref"]).copy()

# Attach FanGraphs ID to Lahman awards using bbrefID → key_bbref
lahman_awards_fg = lahman_awards.merge(
    tr_table_dedup[["key_bbref", "key_fangraphs"]],
    left_on="bbrefID",
    right_on="key_bbref",
    how="left",
    validate="m:1"
)


# -------------------------------------------------------------------
# 3. Merge Lahman(+awards) with FanGraphs batting data on BOTH:
#       key_fangraphs ↔ IDfg   (player)
#       yearID        ↔ Season (year)
# -------------------------------------------------------------------

# Standardize year types
lahman_awards_fg["yearID"] = lahman_awards_fg["yearID"].astype(int)
dfp["Season"]              = dfp["Season"].astype(int)  # rename if needed

awards_pitching = lahman_awards_fg.merge(
    dfp,
    left_on=["key_fangraphs", "yearID"],
    right_on=["IDfg", "Season"],
    how="left",
    validate="m:1"   # each award-year should match at most one batting row
)


# -------------------------------------------------------------------
# 4. (OPTIONAL) You may choose to limit the columns later.
#     The block below is left commented out so you can customize.
# -------------------------------------------------------------------


# Example: columns you *might* want to select later
cols_to_keep = [
    "playerID",
    "bbrefID",
    "full_name",
    "awardID",
    "yearID",
    "lgID",
    "key_fangraphs",   # FanGraphs ID
    "IDfg",
    "W", "L", "ERA", "GS", "G", "CG", "SHO", "SV", "IP", "SO", "K/9", "WHIP", "FIP", "SwStr%", "ERA-", "FIP-",
    "K%", "BB%", "K/9+", "K/BB+", "WHIP+", "AVG+", "K%+", "Hard%+", "Soft%+", "EV", "LA", "Barrel%", "WAR"
    # FG ID in dfp (same as key_fangraphs)
    # Add any batting stat columns here, e.g.:
    # "WAR", "G", "PA", "HR"
]

# # Only keep columns that actually exist
cols_to_keep = [c for c in cols_to_keep if c in awards_pitching.columns]

awards_pitching = awards_pitching[cols_to_keep].copy()

awards_pitching.head()


# If you skip filtering for now, awards_pitching is your full merged dataset:
# print(awards_pitching.head())
# Out:
#      playerID    bbrefID      full_name  \
# 0   aaronha01  aaronha01     Hank Aaron
# 1   aaronha01  aaronha01     Hank Aaron
# 2   aaronha01  aaronha01     Hank Aaron
# 3   aaronha01  aaronha01     Hank Aaron
# 4   aaronha01  aaronha01     Hank Aaron
# 5   aaronha01  aaronha01     Hank Aaron
# 6   aaronha01  aaronha01     Hank Aaron
# 7   aaronha01  aaronha01     Hank Aaron
# 8   aaronha01  aaronha01     Hank Aaron
# 9   aaronha01  aaronha01     Hank Aaron
# 10  aaronha01  aaronha01     Hank Aaron
# 11  aaronha01  aaronha01     Hank Aaron
# 12  aaronha01  aaronha01     Hank Aaron
# 13  aaronha01  aaronha01     Hank Aaron
# 14  aaronha01  aaronha01     Hank Aaron
# 15  aaronha01  aaronha01     Hank Aaron
# 16  aaronha01  aaronha01     Hank Aaron
# 17  aaronha01  aaronha01     Hank Aaron
# 18  aaronha01  aaronha01     Hank Aaron
# 19  aaronha01  aaronha01     Hank Aaron
# 20   aasedo01   aasedo01       Don Aase
# 21   aasedo01   aasedo01       Don Aase
# 22  abbotji01  abbotji01     Jim Abbott
# 23  abbotji01  abbotji01     Jim Abbott
# 24  abbotji01  abbotji01     Jim Abbott
# 25  abernte02  abernte02  Ted Abernathy
# 26  abernte02  abernte02  Ted Abernathy
# 27  abramcj01  abramcj01      CJ Abrams
# 28  abreubo01  abreubo01    Bobby Abreu
# 29  abreubo01  abreubo01    Bobby Abreu
# 30  abreubo01  abreubo01    Bobby Abreu
# 31  abreubo01  abreubo01    Bobby Abreu
# 32  abreubo01  abreubo01    Bobby Abreu
# 33  abreubo01  abreubo01    Bobby Abreu
# 34  abreubo01  abreubo01    Bobby Abreu
# 35  abreubo01  abreubo01    Bobby Abreu
# 36  abreujo02  abreujo02     Jose Abreu
# 37  abreujo02  abreujo02     Jose Abreu
# 38  abreujo02  abreujo02     Jose Abreu
# 39  abreujo02  abreujo02     Jose Abreu
# 40  abreujo02  abreujo02     Jose Abreu
# 41  abreujo02  abreujo02     Jose Abreu
# 42  abreujo02  abreujo02     Jose Abreu
# 43  abreujo02  abreujo02     Jose Abreu
# 44  abreujo02  abreujo02     Jose Abreu
# 45  abreujo02  abreujo02     Jose Abreu
# 46  abreujo02  abreujo02     Jose Abreu
# 47  abreujo02  abreujo02     Jose Abreu
# 48  abreujo02  abreujo02     Jose Abreu
# 49  abreujo02  abreujo02     Jose Abreu
#
#                                   awardID  yearID lgID  key_fangraphs  \
# 0                              Gold Glove    1958   NL      1000001.0
# 1                              Gold Glove    1959   NL      1000001.0
# 2                              Gold Glove    1960   NL      1000001.0
# 3               Lou Gehrig Memorial Award    1970   ML      1000001.0
# 4                    Most Valuable Player    1957   NL      1000001.0
# 5                      Player of the Week    1973   NL      1000001.0
# 6                      Player of the Week    1973   NL      1000001.0
# 7                      Player of the Week    1973   NL      1000001.0
# 8                      Player of the Week    1974   NL      1000001.0
# 9                            TSN All-Star    1956   ML      1000001.0
# 10                           TSN All-Star    1958   ML      1000001.0
# 11                           TSN All-Star    1959   ML      1000001.0
# 12                           TSN All-Star    1963   NL      1000001.0
# 13                           TSN All-Star    1965   NL      1000001.0
# 14                           TSN All-Star    1967   NL      1000001.0
# 15                           TSN All-Star    1969   NL      1000001.0
# 16                           TSN All-Star    1970   NL      1000001.0
# 17                           TSN All-Star    1971   NL      1000001.0
# 18                 TSN Player of the Year    1956   NL      1000001.0
# 19                 TSN Player of the Year    1963   NL      1000001.0
# 20                   Pitcher of the Month    1986   AL      1000003.0
# 21                     Player of the Week    1977   AL      1000003.0
# 22                            Hutch Award    1995   ML      1000012.0
# 23                     Player of the Week    1993   AL      1000012.0
# 24                           TSN All-Star    1991   AL      1000012.0
# 25                TSN Fireman of the Year    1965   NL      1000020.0
# 26                TSN Fireman of the Year    1967   NL      1000020.0
# 27                     Player of the Week    2023   NL        25768.0
# 28                             Gold Glove    2005   NL          945.0
# 29                    Player of the Month    2005   NL          945.0
# 30                    Player of the Month    2009   AL          945.0
# 31                     Player of the Week    2001   NL          945.0
# 32                     Player of the Week    2004   NL          945.0
# 33                     Player of the Week    2005   NL          945.0
# 34                     Player of the Week    2010   AL          945.0
# 35                         Silver Slugger    2004   NL          945.0
# 36             All-MLB Team - Second Team    2020   ML        15676.0
# 37                       Hank Aaron Award    2020   AL        15676.0
# 38  MLB Players Choice Outstanding Player    2020   AL        15676.0
# 39  MLB Players Choice Outstanding Rookie    2014   AL        15676.0
# 40                   Most Valuable Player    2020   AL        15676.0
# 41                    Player of the Month    2014   AL        15676.0
# 42                    Player of the Month    2014   AL        15676.0
# 43                    Player of the Month    2020   AL        15676.0
# 44                    Player of the Month    2021   AL        15676.0
# 45                     Player of the Week    2014   AL        15676.0
# 46                     Player of the Week    2015   AL        15676.0
# 47                     Player of the Week    2015   AL        15676.0
# 48                     Player of the Week    2017   AL        15676.0
# 49                     Player of the Week    2020   AL        15676.0
#
#          IDfg     W     L  ...  K/BB+  WHIP+   AVG+    K%+  Hard%+  Soft%+  \
# 0         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 1         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 2         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 3         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 4         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 5         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 6         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 7         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 8         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 9         NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 10        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 11        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 12        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 13        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 14        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 15        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 16        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 17        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 18        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 19        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 20  1000003.0   6.0   7.0  ...  140.0   88.0   89.0  132.0     NaN     NaN
# 21  1000003.0   6.0   2.0  ...  167.0   82.0   92.0  101.0     NaN     NaN
# 22  1000012.0  11.0   8.0  ...   84.0   94.0  101.0   66.0     NaN     NaN
# 23  1000012.0  11.0  14.0  ...   80.0   97.0  102.0   71.0     NaN     NaN
# 24  1000012.0  18.0  11.0  ...  129.0   89.0   94.0  106.0     NaN     NaN
# 25  1000020.0   4.0   6.0  ...   91.0   98.0   91.0  116.0     NaN     NaN
# 26  1000020.0   6.0   3.0  ...  106.0   78.0   68.0  133.0     NaN     NaN
# 27        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 28        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 29        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 30        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 31        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 32        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 33        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 34        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 35        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 36        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 37        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 38        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 39        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 40        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 41        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 42        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 43        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 44        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 45        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 46        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 47        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 48        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
# 49        NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN     NaN     NaN
#
#     EV  LA  Barrel%  WAR
# 0  NaN NaN      NaN  NaN
# 1  NaN NaN      NaN  NaN
# 2  NaN NaN      NaN  NaN
# 3  NaN NaN      NaN  NaN
# 4  NaN NaN      NaN  NaN
# 5  NaN NaN      NaN  NaN
# 6  NaN NaN      NaN  NaN
# 7  NaN NaN      NaN  NaN
# 8  NaN NaN      NaN  NaN
# 9  NaN NaN      NaN  NaN
# 10 NaN NaN      NaN  NaN
# 11 NaN NaN      NaN  NaN
# 12 NaN NaN      NaN  NaN
# 13 NaN NaN      NaN  NaN
# 14 NaN NaN      NaN  NaN
# 15 NaN NaN      NaN  NaN
# 16 NaN NaN      NaN  NaN
# 17 NaN NaN      NaN  NaN
# 18 NaN NaN      NaN  NaN
# 19 NaN NaN      NaN  NaN
# 20 NaN NaN      NaN  1.9
# 21 NaN NaN      NaN  2.2
# 22 NaN NaN      NaN  3.5
# 23 NaN NaN      NaN  2.3
# 24 NaN NaN      NaN  5.5
# 25 NaN NaN      NaN  1.2
# 26 NaN NaN      NaN  1.8
# 27 NaN NaN      NaN  NaN
# 28 NaN NaN      NaN  NaN
# 29 NaN NaN      NaN  NaN
# 30 NaN NaN      NaN  NaN
# 31 NaN NaN      NaN  NaN
# 32 NaN NaN      NaN  NaN
# 33 NaN NaN      NaN  NaN
# 34 NaN NaN      NaN  NaN
# 35 NaN NaN      NaN  NaN
# 36 NaN NaN      NaN  NaN
# 37 NaN NaN      NaN  NaN
# 38 NaN NaN      NaN  NaN
# 39 NaN NaN      NaN  NaN
# 40 NaN NaN      NaN  NaN
# 41 NaN NaN      NaN  NaN
# 42 NaN NaN      NaN  NaN
# 43 NaN NaN      NaN  NaN
# 44 NaN NaN      NaN  NaN
# 45 NaN NaN      NaN  NaN
# 46 NaN NaN      NaN  NaN
# 47 NaN NaN      NaN  NaN
# 48 NaN NaN      NaN  NaN
# 49 NaN NaN      NaN  NaN
#
# [50 rows x 36 columns]

# %%
import pandas as pd

# 1. Load your datasets
# Replace 'teams.csv' and 'batters.csv' with your actual file paths

# 2. Merge Batters with Teams to get the League ID
# We assume the batters dataset has a 'teamID' column to link with the teams dataset.

dfp['WAR'] = pd.to_numeric(dfp['WAR'], errors='coerce')

merged_df = pd.merge(
    dfp, 
    df_teams[['yearID', 'franchID', 'lgID']], 
    left_on=['Season', 'Team'],
    right_on=['yearID', 'franchID'],
    how='left'
)

# 3. Aggregate WAR by Player, Year, and League
# This step handles cases where a player played for multiple teams 
# within the same league in a single year (summing their WAR).
player_league_war = merged_df.groupby(['yearID', 'lgID', 'IDfg'], as_index=False)['WAR'].sum()

# 4. Calculate the Max WAR for each Year and League
# We transform the data to add a column with the max WAR for that group
player_league_war['max_WAR'] = player_league_war.groupby(['yearID', 'lgID'])['WAR'].transform('max')

# 5. Create the WAR Leader Flag
# Flag is True (or 1) if the player's WAR equals the max WAR for that league/year
player_league_war['WAR_leader_flag'] = (player_league_war['WAR'] == player_league_war['max_WAR']).astype(int)

# 6. Select and Rename Columns for Final Output
output_df = player_league_war[['IDfg', 'yearID', 'lgID', 'WAR_leader_flag']].copy()
output_df.columns = ['IDfg', 'year', 'league', 'WAR leader flag']

# Display the first few rows
print(output_df.head())

# Optional: Save to a new CSV
output_df.to_csv('war_leaders.csv', index=False)
# Out:
#       IDfg    year league  WAR leader flag
# 0  1000460  1911.0     AL                0
# 1  1000860  1911.0     AL                0
# 2  1001045  1911.0     AL                0
# 3  1002236  1911.0     AL                0
# 4  1002462  1911.0     AL                0

# %%
player_league_war['WAR'].dtype
# Out:
# dtype('float64')

# %%
war_leaders = output_df.copy()

# %%
war_leaders
# Out:
#           IDfg    year league  WAR leader flag
# 0      1000460  1911.0     AL                0
# 1      1000860  1911.0     AL                0
# 2      1001045  1911.0     AL                0
# 3      1002236  1911.0     AL                0
# 4      1002462  1911.0     AL                0
# ...        ...     ...    ...              ...
# 21501    31846  2024.0     NL                0
# 21502    33677  2024.0     NL                0
# 21503    33825  2024.0     NL                0
# 21504    33826  2024.0     NL                0
# 21505    33829  2024.0     NL                0
#
# [21506 rows x 4 columns]

# %%
war_leaders['year'] = war_leaders['year'].astype('int64')
awards_pitching['yearID'] = awards_pitching['yearID'].astype('int64')

# %%
import numpy as np
import pandas as pd

# clean the strings first
awards_pitching['key_fangraphs'] = (
    awards_pitching['key_fangraphs']
      .astype(str)
      .str.strip()
      .str.replace('.0', '', regex=False)
)

# turn impossible values into NaN, then use nullable Int64
awards_pitching['key_fangraphs'] = pd.to_numeric(
    awards_pitching['key_fangraphs'],
    errors='coerce'        # 'nan', '', junk -> NaN
).astype('Int64')          # pandas nullable integer dtype

# %%
awards_pitching
# Out:
#         playerID    bbrefID    full_name  \
# 0      aaronha01  aaronha01   Hank Aaron
# 1      aaronha01  aaronha01   Hank Aaron
# 2      aaronha01  aaronha01   Hank Aaron
# 3      aaronha01  aaronha01   Hank Aaron
# 4      aaronha01  aaronha01   Hank Aaron
# ...          ...        ...          ...
# 12457  zobribe01  zobribe01  Ben Zobrist
# 12458  zobribe01  zobribe01  Ben Zobrist
# 12459  zobribe01  zobribe01  Ben Zobrist
# 12460  zobribe01  zobribe01  Ben Zobrist
# 12461  zumayjo01  zumayjo01  Joel Zumaya
#
#                                            awardID  yearID lgID  \
# 0                                       Gold Glove    1958   NL
# 1                                       Gold Glove    1959   NL
# 2                                       Gold Glove    1960   NL
# 3                        Lou Gehrig Memorial Award    1970   ML
# 4                             Most Valuable Player    1957   NL
# ...                                            ...     ...  ...
# 12457                           Player of the Week    2008   AL
# 12458                           Player of the Week    2011   AL
# 12459                           Player of the Week    2016   NL
# 12460                             World Series MVP    2016   ML
# 12461  This Year in Baseball Setup Man of the Year    2006   ML
#
#        key_fangraphs    IDfg    W    L  ...  K/BB+  WHIP+  AVG+    K%+  \
# 0            1000001     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# 1            1000001     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# 2            1000001     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# 3            1000001     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# 4            1000001     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# ...              ...     ...  ...  ...  ...    ...    ...   ...    ...
# 12457           7435     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# 12458           7435     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# 12459           7435     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# 12460           7435     NaN  NaN  NaN  ...    NaN    NaN   NaN    NaN
# 12461           4699  4699.0  6.0  3.0  ...  114.0   83.0  68.0  168.0
#
#        Hard%+  Soft%+  EV  LA  Barrel%  WAR
# 0         NaN     NaN NaN NaN      NaN  NaN
# 1         NaN     NaN NaN NaN      NaN  NaN
# 2         NaN     NaN NaN NaN      NaN  NaN
# 3         NaN     NaN NaN NaN      NaN  NaN
# 4         NaN     NaN NaN NaN      NaN  NaN
# ...       ...     ...  ..  ..      ...  ...
# 12457     NaN     NaN NaN NaN      NaN  NaN
# 12458     NaN     NaN NaN NaN      NaN  NaN
# 12459     NaN     NaN NaN NaN      NaN  NaN
# 12460     NaN     NaN NaN NaN      NaN  NaN
# 12461    80.0   115.0 NaN NaN      NaN  2.0
#
# [12462 rows x 36 columns]

# %%
pitching_final = pd.merge(
    awards_pitching,
    war_leaders,
    left_on=['key_fangraphs', 'yearID'],
    right_on=['IDfg', 'year'],
    how='left'
)

# %%
pitching_final.loc[batting_final['key_fangraphs']== 2036]
# Out:
#        playerID    bbrefID        full_name  \
# 6067  kershcl01  kershcl01  Clayton Kershaw
# 6068  kershcl01  kershcl01  Clayton Kershaw
# 6069  kershcl01  kershcl01  Clayton Kershaw
# 6070  kershcl01  kershcl01  Clayton Kershaw
# 6071  kershcl01  kershcl01  Clayton Kershaw
# 6072  kershcl01  kershcl01  Clayton Kershaw
# 6073  kershcl01  kershcl01  Clayton Kershaw
# 6074  kershcl01  kershcl01  Clayton Kershaw
# 6075  kershcl01  kershcl01  Clayton Kershaw
# 6076  kershcl01  kershcl01  Clayton Kershaw
# 6077  kershcl01  kershcl01  Clayton Kershaw
# 6078  kershcl01  kershcl01  Clayton Kershaw
# 6079  kershcl01  kershcl01  Clayton Kershaw
# 6080  kershcl01  kershcl01  Clayton Kershaw
# 6081  kershcl01  kershcl01  Clayton Kershaw
# 6082  kershcl01  kershcl01  Clayton Kershaw
# 6083  kershcl01  kershcl01  Clayton Kershaw
# 6084  kershcl01  kershcl01  Clayton Kershaw
# 6085  kershcl01  kershcl01  Clayton Kershaw
# 6086  kershcl01  kershcl01  Clayton Kershaw
# 6087  kershcl01  kershcl01  Clayton Kershaw
# 6088  kershcl01  kershcl01  Clayton Kershaw
# 6089  kershcl01  kershcl01  Clayton Kershaw
# 6090  kershcl01  kershcl01  Clayton Kershaw
# 6091  kershcl01  kershcl01  Clayton Kershaw
# 6092  kershcl01  kershcl01  Clayton Kershaw
# 6093  kershcl01  kershcl01  Clayton Kershaw
# 6094  kershcl01  kershcl01  Clayton Kershaw
# 6095  kershcl01  kershcl01  Clayton Kershaw
# 6096  kershcl01  kershcl01  Clayton Kershaw
# 6097  kershcl01  kershcl01  Clayton Kershaw
# 6098  kershcl01  kershcl01  Clayton Kershaw
# 6099  kershcl01  kershcl01  Clayton Kershaw
# 6100  kershcl01  kershcl01  Clayton Kershaw
#
#                                                 awardID  yearID lgID  \
# 6067                         All-MLB Team - Second Team    2020   ML
# 6068                                Branch Rickey Award    2013   ML
# 6069                                     Cy Young Award    2011   NL
# 6070                                     Cy Young Award    2013   NL
# 6071                                     Cy Young Award    2014   NL
# 6072                                         Gold Glove    2011   NL
# 6073                 MLB Players Choice Man of the Year    2014   ML
# 6074             MLB Players Choice Outstanding Pitcher    2011   NL
# 6075             MLB Players Choice Outstanding Pitcher    2013   NL
# 6076             MLB Players Choice Outstanding Pitcher    2014   NL
# 6077              MLB Players Choice Player of the Year    2014   ML
# 6078                               Most Valuable Player    2014   NL
# 6079                               Pitcher of the Month    2011   NL
# 6080                               Pitcher of the Month    2013   NL
# 6081                               Pitcher of the Month    2014   NL
# 6082                               Pitcher of the Month    2014   NL
# 6083                               Pitcher of the Month    2015   NL
# 6084                               Pitcher of the Month    2016   NL
# 6085                               Pitcher of the Month    2023   NL
# 6086                              Pitching Triple Crown    2011   NL
# 6087                                 Player of the Week    2011   NL
# 6088                                 Player of the Week    2012   NL
# 6089                                 Player of the Week    2013   NL
# 6090                                 Player of the Week    2014   NL
# 6091                                 Player of the Week    2014   NL
# 6092                                 Player of the Week    2015   NL
# 6093                                 Player of the Week    2015   NL
# 6094                                 Player of the Week    2017   NL
# 6095                             Roberto Clemente Award    2012   ML
# 6096  This Year in Baseball Pitching Performance of ...    2014   ML
# 6097          This Year in Baseball Starter of the Year    2013   ML
# 6098          This Year in Baseball Starter of the Year    2014   ML
# 6099                TSN Major League Player of the Year    2014   ML
# 6100                            TSN Pitcher of the Year    2011   NL
#
#       key_fangraphs  IDfg_x     W    L  ...  Hard%+  Soft%+    EV    LA  \
# 6067           2036  2036.0   6.0  2.0  ...   100.0    96.0  87.8   7.9
# 6068           2036  2036.0  16.0  9.0  ...    97.0    86.0   NaN   NaN
# 6069           2036  2036.0  21.0  5.0  ...    78.0   116.0   NaN   NaN
# 6070           2036  2036.0  16.0  9.0  ...    97.0    86.0   NaN   NaN
# 6071           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6072           2036  2036.0  21.0  5.0  ...    78.0   116.0   NaN   NaN
# 6073           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6074           2036  2036.0  21.0  5.0  ...    78.0   116.0   NaN   NaN
# 6075           2036  2036.0  16.0  9.0  ...    97.0    86.0   NaN   NaN
# 6076           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6077           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6078           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6079           2036  2036.0  21.0  5.0  ...    78.0   116.0   NaN   NaN
# 6080           2036  2036.0  16.0  9.0  ...    97.0    86.0   NaN   NaN
# 6081           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6082           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6083           2036  2036.0  16.0  7.0  ...    86.0   108.0  85.6   8.9
# 6084           2036  2036.0  12.0  4.0  ...    90.0   108.0  86.9   9.4
# 6085           2036  2036.0  13.0  5.0  ...   101.0    99.0  89.0  11.8
# 6086           2036  2036.0  21.0  5.0  ...    78.0   116.0   NaN   NaN
# 6087           2036  2036.0  21.0  5.0  ...    78.0   116.0   NaN   NaN
# 6088           2036  2036.0  14.0  9.0  ...    89.0   129.0   NaN   NaN
# 6089           2036  2036.0  16.0  9.0  ...    97.0    86.0   NaN   NaN
# 6090           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6091           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6092           2036  2036.0  16.0  7.0  ...    86.0   108.0  85.6   8.9
# 6093           2036  2036.0  16.0  7.0  ...    86.0   108.0  85.6   8.9
# 6094           2036  2036.0  18.0  4.0  ...    87.0   121.0  85.3  10.3
# 6095           2036  2036.0  14.0  9.0  ...    89.0   129.0   NaN   NaN
# 6096           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6097           2036  2036.0  16.0  9.0  ...    97.0    86.0   NaN   NaN
# 6098           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6099           2036  2036.0  21.0  3.0  ...    82.0   133.0   NaN   NaN
# 6100           2036  2036.0  21.0  5.0  ...    78.0   116.0   NaN   NaN
#
#       Barrel%  WAR  IDfg_y    year  league  WAR leader flag
# 6067    0.080  1.4  2036.0  2020.0      NL              0.0
# 6068      NaN  7.2  2036.0  2013.0      NL              1.0
# 6069      NaN  7.3  2036.0  2011.0      NL              0.0
# 6070      NaN  7.2  2036.0  2013.0      NL              1.0
# 6071      NaN  7.9  2036.0  2014.0      NL              1.0
# 6072      NaN  7.3  2036.0  2011.0      NL              0.0
# 6073      NaN  7.9  2036.0  2014.0      NL              1.0
# 6074      NaN  7.3  2036.0  2011.0      NL              0.0
# 6075      NaN  7.2  2036.0  2013.0      NL              1.0
# 6076      NaN  7.9  2036.0  2014.0      NL              1.0
# 6077      NaN  7.9  2036.0  2014.0      NL              1.0
# 6078      NaN  7.9  2036.0  2014.0      NL              1.0
# 6079      NaN  7.3  2036.0  2011.0      NL              0.0
# 6080      NaN  7.2  2036.0  2013.0      NL              1.0
# 6081      NaN  7.9  2036.0  2014.0      NL              1.0
# 6082      NaN  7.9  2036.0  2014.0      NL              1.0
# 6083    0.033  8.6  2036.0  2015.0      NL              1.0
# 6084    0.045  6.3  2036.0  2016.0      NL              1.0
# 6085    0.090  2.4  2036.0  2023.0      NL              0.0
# 6086      NaN  7.3  2036.0  2011.0      NL              0.0
# 6087      NaN  7.3  2036.0  2011.0      NL              0.0
# 6088      NaN  6.1  2036.0  2012.0      NL              1.0
# 6089      NaN  7.2  2036.0  2013.0      NL              1.0
# 6090      NaN  7.9  2036.0  2014.0      NL              1.0
# 6091      NaN  7.9  2036.0  2014.0      NL              1.0
# 6092    0.033  8.6  2036.0  2015.0      NL              1.0
# 6093    0.033  8.6  2036.0  2015.0      NL              1.0
# 6094    0.063  4.3  2036.0  2017.0      NL              0.0
# 6095      NaN  6.1  2036.0  2012.0      NL              1.0
# 6096      NaN  7.9  2036.0  2014.0      NL              1.0
# 6097      NaN  7.2  2036.0  2013.0      NL              1.0
# 6098      NaN  7.9  2036.0  2014.0      NL              1.0
# 6099      NaN  7.9  2036.0  2014.0      NL              1.0
# 6100      NaN  7.3  2036.0  2011.0      NL              0.0
#
# [34 rows x 40 columns]

# %%
cy = pitching_final.loc[pitching_final['awardID'] == 'Cy Young Award']

# %%
cy
# Out:
#         playerID    bbrefID        full_name         awardID  yearID lgID  \
# 117    alcansa01  alcansa01  Sandy Alcantara  Cy Young Award    2022   NL
# 431    arrieja01  arrieja01     Jake Arrieta  Cy Young Award    2015   NL
# 631    bauertr01  bauertr01     Trevor Bauer  Cy Young Award    2020   NL
# 708    bedrost01  bedrost01  Steve Bedrosian  Cy Young Award    1987   NL
# 1014   biebesh01  biebesh01     Shane Bieber  Cy Young Award    2020   AL
# ...          ...        ...              ...             ...     ...  ...
# 11747  vuckope01  vuckope01   Pete Vuckovich  Cy Young Award    1982   AL
# 11906   webbbr01   webbbr01     Brandon Webb  Cy Young Award    2006   NL
# 11914  welchbo01  welchbo01        Bob Welch  Cy Young Award    1990   AL
# 12286   wynnea01   wynnea01       Early Wynn  Cy Young Award    1959   ML
# 12446   zitoba01   zitoba01       Barry Zito  Cy Young Award    2002   AL
#
#        key_fangraphs     IDfg_x     W     L  ...  Hard%+  Soft%+    EV    LA  \
# 117            18684    18684.0  14.0   9.0  ...    87.0   126.0  87.8   5.5
# 431             4153     4153.0  22.0   6.0  ...    75.0   123.0  85.1   4.4
# 631            12703    12703.0   5.0   4.0  ...    76.0   122.0  88.5  20.9
# 708          1000766  1000766.0   5.0   3.0  ...     NaN     NaN   NaN   NaN
# 1014           19427    19427.0   8.0   1.0  ...    81.0   124.0  89.3   9.6
# ...              ...        ...   ...   ...  ...     ...     ...   ...   ...
# 11747        1013461  1013461.0  18.0   6.0  ...     NaN     NaN   NaN   NaN
# 11906           1692     1692.0  16.0   8.0  ...    90.0   110.0   NaN   NaN
# 11914        1013750  1013750.0  27.0   6.0  ...     NaN     NaN   NaN   NaN
# 12286        1014309  1014309.0  22.0  10.0  ...     NaN     NaN   NaN   NaN
# 12446            944      944.0  23.0   5.0  ...    87.0   127.0   NaN   NaN
#
#        Barrel%  WAR     IDfg_y    year  league  WAR leader flag
# 117      0.053  5.9        NaN     NaN     NaN              NaN
# 431      0.022  7.0     4153.0  2015.0      NL              0.0
# 631      0.063  2.6    12703.0  2020.0      NL              0.0
# 708        NaN  0.8  1000766.0  1987.0      NL              0.0
# 1014     0.072  3.1    19427.0  2020.0      AL              1.0
# ...        ...  ...        ...     ...     ...              ...
# 11747      NaN  2.4  1013461.0  1982.0      AL              0.0
# 11906      NaN  6.5     1692.0  2006.0      NL              1.0
# 11914      NaN  1.8  1013750.0  1990.0      AL              0.0
# 12286      NaN  3.6  1014309.0  1959.0      AL              0.0
# 12446      NaN  4.5      944.0  2002.0      AL              0.0
#
# [128 rows x 40 columns]

# %%
cy.to_csv('/Users/ryan/Desktop/STAT5702GR/final_project/cy_young_pitching_dataset_rev.csv')

# %%
pitching_final.to_csv('/Users/ryan/Desktop/STAT5702GR/final_project/pitching_dataset_all.csv')
